# %%
import langchain
langchain.__version__
# Out:
# '0.3.27'

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model = 'gpt-4o-mini')
llm
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x0000026901F5F620>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000026901B03FB0>, root_client=<openai.OpenAI object at 0x0000026901B026F0>, root_async_client=<openai.AsyncOpenAI object at 0x000002690061A8A0>, model_name='gpt-4o-mini', model_kwargs={}, openai_api_key=SecretStr('**********'))

# %%
messages = [
    ('system', '당신은 서울의 음식과 문화 전문가입니다.'),
    ('human', '서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해 주세요.')
]

res = llm.invoke(messages)

# %%
res.content
# Out:
# '서울에서 전통적인 한국 음식을 맛볼 수 있는 레스토랑 5곳을 추천드립니다.\n\n1. **광장시장** - 이곳은 서울의 대표적인 전통 시장으로, 다양한 길거리 음식을 맛볼 수 있습니다. 특히 빈대떡, 육회, 그리고 순대가 유명합니다.\n\n2. **삼청동 수라간** - 전통 한정식을 경험할 수 있는 곳으로, 세련된 한옥 분위기에서 계절별 신선한 재료로 만든 정갈한 반찬을 맛볼 수 있습니다.\n\n3. **신당동 떡볶이 타운** - 이곳은 신당동에 위치한 여러 떡볶이 집들이 모여있는 지역입니다. 매콤하고 달콤한 떡볶이를 비롯해 순대와 오뎅을 함께 즐길 수 있는 최적의 장소입니다.\n\n4. **계동 해장국** - 해장국의 본고장으로 알려진 이곳에서는 진하고 깊은 맛의 해장국을 맛볼 수 있습니다. 다음날의 숙취를 해소해주는 국물 맛이 일품입니다.\n\n5. **를지로 피자** - 현대적인 한국 피자를 제공하며, 전통 재료를 활용해 색다른 경험을 선사합니다. 특히 이곳의 김치 피자는 많은 사랑을 받고 있습니다.\n\n서울의 다양한 음식 문화를 경험하며 맛있게 즐기시길 바랍니다!'

# %%
messages = [
    [('system', '당신은 서울의 음식과 문화 전문가입니다.'), ('human', '서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해 주세요.')],
    [('system', '당신은 연애 전문가입니다.'), ('human', '서울 데이트 장소 5개를 추천해주세요.')]
]

response = llm.batch(messages)
response
# Out:
# [AIMessage(content='서울에서 대표적인 음식을 맛볼 수 있는 레스토랑 5곳을 추천해드리겠습니다.\n\n1. **진주회관**  \n   - **추천 메뉴**: 불고기\n   - 진주회관은 전통적인 불고기를 맛볼 수 있는 명소로, 질 좋은 한우와 신선한 재료를 사용해 고소하고 부드러운 불고기를 제공합니다.\n\n2. **광장시장**  \n   - **추천 메뉴**: 빈대떡 & 마약김밥\n   - 광장시장은 다양한 먹거리가 가득한 전통 시장입니다. 빈대떡과 함께 ‘마약김밥’으로 유명한 김밥도 꼭 한번 맛보세요.\n\n3. **육회자매**  \n   - **추천 메뉴**: 육회\n   - 이곳은 신선한 한우 육회를 전문으로 하는 레스토랑입니다. 부드러운 육회와 함께 제공되는 고추장 소스가 일품입니다.\n\n4. **신선설농탕**  \n   - **추천 메뉴**: 설렁탕\n   - 설렁탕의 명소로, 진한 국물과 부드러운 소고기를 맛볼 수 있습니다. 자작한 국물에 밥과 함께 즐기면 훌륭한 한 끼가 됩니다.\n\n5. **명동교자**  \n   - **추천 메뉴**: 칼국수\n   - 명동에 위치한 명동교자는 수제 면발과 깊은 맛의 국물이 일품인 칼국수로 유명합니다. 칼국수 외에도 만두도 추천합니다.\n\n이 레스토랑들은 각기 다른 서울의 전통 음식을 대표하는 곳으로, 맛과 분위기 모두 추천할 만한 곳들입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 387, 'prompt_tokens': 43, 'total_tokens': 430, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-C7CpW1bQ8JlY8UTBMsvQRgwJvJ7YN', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--2c0e1a31-50cf-4c8c-9218-6f81594cf4a5-0', usage_metadata={'input_tokens': 43, 'output_tokens': 387, 'total_tokens': 430, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='서울에는 다양한 매력적인 데이트 장소가 많습니다. 아래는 추천하는 다섯 곳입니다.\n\n1. **한강공원**: 한강을 따라 펼쳐진 여러 공원에서는 자전거 타기, 산책, 피크닉을 즐길 수 있습니다. 여름철엔 야경을 감상하며 밤나들이도 좋습니다.\n\n2. **북촌한옥마을**: 전통 한옥이 아름답게 보존된 북촌은 고즈넉한 분위기 속에서 산책하며 한국의 전통 문화를 느낄 수 있는 장소입니다.\n\n3. **이태원**: 다양한 음식과 문화가 공존하는 이태원은 이국적인 카페와 레스토랑이 많아 색다른 데이트를 즐기기에 좋은 곳입니다. 또한, 이태원 거리의 아름다운 야경도 매력적입니다.\n\n4. **경복궁**: 서울의 대표적인 고궁인 경복궁은 아름다운 한옥과 정원이 있어 로맨틱한 분위기에서 산책할 수 있습니다. 궁궐 투어 후 명화당에서 차 한 잔의 여유를 즐기는 것도 좋습니다.\n\n5. **홍대 거리**: 젊음과 창의성의 상징인 홍대는 다양한 카페와 맛집, 아트 갤러리, 거리 공연이 풍부하여 사람들과 어울리기 좋은 분위기입니다. 맛있는 디저트를 즐기거나 공연을 관람하며 특별한 시간을 보낼 수 있습니다.\n\n각 장소마다 특징이 있어 취향에 맞게 선택하셔서 즐거운 데이트 되시길 바랍니다!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 355, 'prompt_tokens': 30, 'total_tokens': 385, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-C7CpWQ12B5tjxkiXrAVs5Ig7CKh4t', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--41e043cc-61ac-4146-ad93-60288bc51d4e-0', usage_metadata={'input_tokens': 30, 'output_tokens': 355, 'total_tokens': 385, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
for res in response:
    print(res.content)
# Out:
# 서울에서 대표적인 음식을 맛볼 수 있는 레스토랑 5곳을 추천해드리겠습니다.
#
# 1. **진주회관**
#    - **추천 메뉴**: 불고기
#    - 진주회관은 전통적인 불고기를 맛볼 수 있는 명소로, 질 좋은 한우와 신선한 재료를 사용해 고소하고 부드러운 불고기를 제공합니다.
#
# 2. **광장시장**
#    - **추천 메뉴**: 빈대떡 & 마약김밥
#    - 광장시장은 다양한 먹거리가 가득한 전통 시장입니다. 빈대떡과 함께 ‘마약김밥’으로 유명한 김밥도 꼭 한번 맛보세요.
#
# 3. **육회자매**
#    - **추천 메뉴**: 육회
#    - 이곳은 신선한 한우 육회를 전문으로 하는 레스토랑입니다. 부드러운 육회와 함께 제공되는 고추장 소스가 일품입니다.
#
# 4. **신선설농탕**
#    - **추천 메뉴**: 설렁탕
#    - 설렁탕의 명소로, 진한 국물과 부드러운 소고기를 맛볼 수 있습니다. 자작한 국물에 밥과 함께 즐기면 훌륭한 한 끼가 됩니다.
#
# 5. **명동교자**
#    - **추천 메뉴**: 칼국수
#    - 명동에 위치한 명동교자는 수제 면발과 깊은 맛의 국물이 일품인 칼국수로 유명합니다. 칼국수 외에도 만두도 추천합니다.
#
# 이 레스토랑들은 각기 다른 서울의 전통 음식을 대표하는 곳으로, 맛과 분위기 모두 추천할 만한 곳들입니다.
# 서울에는 다양한 매력적인 데이트 장소가 많습니다. 아래는 추천하는 다섯 곳입니다.
#
# 1. **한강공원**: 한강을 따라 펼쳐진 여러 공원에서는 자전거 타기, 산책, 피크닉을 즐길 수 있습니다. 여름철엔 야경을 감상하며 밤나들이도 좋습니다.
#
# 2. **북촌한옥마을**: 전통 한옥이 아름답게 보존된 북촌은 고즈넉한 분위기 속에서 산책하며 한국의 전통 문화를 느낄 수 있는 장소입니다.
#
# 3. **이태원**: 다양한 음식과 문화가 공존하는 이태원은 이국적인 카페와 레스토랑이 많아 색다른 데이트를 즐기기에 좋은 곳입니다. 또한, 이태원 거리의 아름다운 야경도 매력적입니다.
#
# 4. **경복궁**: 서울의 대표적인 고궁인 경복궁은 아름다운 한옥과 정원이 있어 로맨틱한 분위기에서 산책할 수 있습니다. 궁궐 투어 후 명화당에서 차 한 잔의 여유를 즐기는 것도 좋습니다.
#
# 5. **홍대 거리**: 젊음과 창의성의 상징인 홍대는 다양한 카페와 맛집, 아트 갤러리, 거리 공연이 풍부하여 사람들과 어울리기 좋은 분위기입니다. 맛있는 디저트를 즐기거나 공연을 관람하며 특별한 시간을 보낼 수 있습니다.
#
# 각 장소마다 특징이 있어 취향에 맞게 선택하셔서 즐거운 데이트 되시길 바랍니다!

# %%
messages = [
    ('system', '당신은 서울의 음식과 문화 전문가입니다.'),
    ('human', '서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해 주세요.')
]

response = llm.stream(messages)

for res in response:
    print(res.content, end='')
# Out:
# 서울에서 대표적인 음식을 맛볼 수 있는 레스토랑 5곳을 추천해 드리겠습니다.
#
# 1. **광장시장 (Gwangjang Market)**
#    - 전통 시장으로, 다양한 한국 음식을 한 곳에서 즐길 수 있습니다. 특히 비빔밥, 빈대떡, 마른 오징어와 함께하는 막걸리 등을 맛볼 수 있습니다. 시장의 활기찬 분위기와 함께 진정한 한국의 맛을 경험해 보세요.
#
# 2. **삼거리포차 (Samgyeori Pocha)**
#    - 전통적인 포장마차 스타일의 레스토랑으로, 주로 해물과 고기를 구워 제공하는 곳입니다. 특히 삼겹살과 소주를 함께 즐기며, 한국의 야경도 만끽할 수 있습니다. 다양한 안주와 함께 한국의 술 문화를 체험할 수 있습니다.
#
# 3. **백년옥 (Baengnyeonok)**
#    - 전통 한식당으로, 손수 만든 두부와 함께 나오는 전통 한정식을 전문으로 합니다. 특히 두부찌개와 비빔밥이 유명합니다. 조용하고 아늑한 분위기에서 진정한 한국의 집밥을 느껴보세요.
#
# 4. **명동교자 (Myeongdong Kyoja)**
#    - 면 요리 전문점으로, 칼국수와 만두가 유명한 곳입니다. 손으로 만든 칼국수는 쫄깃하고 국물 맛이 일품이며, 만두는 담백한 맛으로 많은 사람들에게 사랑받고 있습니다. 명동의 쇼핑과 함께 방문해 보세요.
#
# 5. **토속촌삼계탕 (Tosokchon Samgyetang)**
#    - 서울의 대표적인 삼계탕 전문점으로, 깊고 진한 국물의 삼계탕을 제공합니다. 특유의 부드러운 닭과 쌀, 한약재가 어우러져 영양가 높은 한 끼 식사를 할 수 있습니다. 한국의 보양식을 경험해 보세요.
#
# 이 한국 음식의 대표적인 맛을 경험하기에 좋은 장소들입니다. 각 레스토랑의 독특한 분위기와 메뉴를 즐겨보세요!

# %% [markdown]
# # async, sync

# %%
import asyncio
import time

async def invoke_async(llm, messages):
    response = await llm.ainvoke(messages)
    print(response.content)

async def invoke_parallel(llm, messages):
    tasks = [invoke_async(llm, messages) for _ in range(10)]
    await asyncio.gather(*tasks)

# %% [markdown]
# ## async

# %%
messages = [
    ('system', '당신은 서울의 음식과 문화 전문가입니다.'),
    ('human', '서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해 주세요.')
]

start = time.perf_counter()

await invoke_parallel(llm, messages)

end = time.perf_counter()

print(f"Elapsed time: {end - start:.2f} seconds")
# Out:
# 서울은 다양한 전통 음식과 현대식 요리를 즐길 수 있는 곳입니다. 다음은 서울을 대표하는 음식을 맛볼 수 있는 추천 레스토랑 5곳입니다.
#
# 1. **광화문 안풍**
#    - 전통 한정식 전문점으로, 다양한 반찬과 함께 제공되는 정갈한 한식을 경험할 수 있습니다. 특히 제철 재료를 사용한 메뉴가 인상적입니다.
#
# 2. **명동교자**
#    - 한국식 칼국수와 만두의 대표 주자로, 특히 고기 만두와 칼국수의 조합이 유명합니다. 넉넉한 양과 깊은 맛이 매력적입니다.
#
# 3. **삼겹살의 정석 – 가마솥 사랑**
#    - 서울에서 유명한 삼겹살 전문점으로, 무한리필 삼겹살을 제공하며 직접 구워먹는 재미가 있습니다. 신선한 재료와 고소한 맛을 자랑합니다.
#
# 4. **송추가마골**
#    - 서울 외곽에 위치한 유명한 한정식과 고기 전문점으로, 특히 장어구이가 일품입니다. 신선한 재료와 정성 가득한 요리가 매력적입니다.
#
# 5. **비스트로 모모**
#    - 현대적인 한국 식당으로, 케이블카 송추캠핑장 내에 위치해 있습니다. 전통 한국 요리를 현대적으로 재해석한 메뉴가 특징이며, 분위기 또한 아늑합니다.
#
# 이곳들에서는 서울의 특색 있는 음식을 즐기면서 그곳만의 독특한 분위기를 체험할 수 있습니다. 예약을 권장하며, 각 레스토랑의 운영 시간을 확인하는 것도 좋습니다!
# 서울에서 전통적인 한국 음식을 맛볼 수 있는 레스토랑 5곳을 추천드립니다.
#
# 1. **창고43 (Changgo43)**
#    - **위치**: 이태원
#    - **특징**: 전통 한식의 현대적인 해석으로 유명합니다. 제철 재료를 활용한 정갈한 한식을 제공하며, 분위기가 좋아 데이트나 특별한 자리에도 적합합니다.
#
# 2. **백암순대 (Baegam Sundae)**
#    - **위치**: 을지로
#    - **특징**: 순대국밥과 순대를 전문으로 하는 곳으로, 깊고 진한 국물 맛이 일품입니다. 서울의 전통적인 음식 문화가 살아있는 곳으로, 한국인들에게도 사랑받는 맛집입니다.
#
# 3. **광장시장 (Gwangjang Market)**
#    - **위치**: 종로
#    - **특징**: 다양한 전통 음식을 한 곳에서 맛볼 수 있는 시장입니다. 특히 빈대떡, 마약김밥, 순대 등 다양한 길거리 음식을 경험할 수 있습니다. 분위기와 함께하는 한국 전통 맛이 매력입니다.
#
# 4. **미진 (Mijin)**
#    - **위치**: 여의도
#    - **특징**: 직화로 구워낸 갈비와 비빔밥이 인기입니다. 특히, 와인과 함께 즐길 수 있는 한식 메뉴가 많아 색다른 경험을 제공합니다.
#
# 5. **안주식당 (Anju Sikdang)**
#    - **위치**: 홍대
#    - **특징**: 다양한 한국 전통 안주와 술을 즐길 수 있는 곳으로, 김치전, 해물파전 등이 유명합니다. 편안한 분위기에서 친구들과 함께 즐기기에 좋은 장소입니다.
#
# 이 레스토랑들은 서울의 전통 한식을 잘 나타내고 있으며, 각기 다른 매력을 가지고 있어 다양한 경험을 할 수 있습니다. 즐거운 식사 시간 되시길 바랍니다!
# 서울에서 대표적인 음식들을 맛볼 수 있는 레스토랑 5곳을 추천해드릴게요!
#
# 1. **광장시장 - 마포순대**
#    - 순대와 다양한 전통 음식을 즐길 수 있는 곳으로, 특히 순대국이 인기입니다. 광장시장에서 다양한 한국 전통 음식을 경험해 보세요.
#
# 2. **백리향 (Bai Li Xiang)**
#    - 서울에서 유명한 중식당으로, 정통 북경오리 요리와 다양한 중국식 사천 요리를 선보입니다. 고급스러운 분위기에서 훌륭한 중식 요리를 맛볼 수 있습니다.
#
# 3. **신당동떡볶이**
#    - 이곳은 여러 가지 종류의 떡볶이를 전문으로 하는 식당들로 유명해요. 매운 떡볶이부터 다양한 토핑이 있는 메뉴까지 선택할 수 있습니다. 간식으로 또는 간단한 식사로 즐기기 좋은 곳입니다.
#
# 4. **부엌**
#    - 현대적인 한국 전통 요리를 모던하고 창의적으로 재해석한 레스토랑입니다. 제철 재료를 사용해 만든 다양한 한식 요리를 주문할 수 있습니다.
#
# 5. **을지로 골뱅이집**
#    - 술과 잘 어울리는 안주를 맛볼 수 있는 곳으로, 특별히 골뱅이 무침이 유명합니다. 분위기도 아늑하고, 세련된 맛의 한국식 안주를 즐길 수 있습니다.
#
# 각 레스토랑은 서울만의 독특한 맛을 경험할 수 있는 곳들로, 방문해 보시면 좋을 것 같습니다!
# 서울에서 대표적인 음식을 맛볼 수 있는 레스토랑 5곳을 추천해 드립니다.
#
# 1. **광장시장** - 이곳은 서울의 전통 시장 중 하나로, 다양한 길거리 음식을 즐길 수 있습니다. 특히, 빈대떡, 마켓비의 떡볶이, 전통 순대 등을 꼭 맛보시길 추천합니다.
#
# 2. **상암동 "한우명가"** - 한우를 전문으로 하는 이 식당은 풍부한 맛의 한우 불고기와 육회가 유명합니다. 질 좋은 한우를 사용하여 한국 고유의 맛을 제대로 느낄 수 있습니다.
#
# 3. **명동 "부추전"** - 이곳은 부추전과 함께 막걸리를 즐길 수 있는 전통 한국 음식점입니다. 바삭한 부추전과 함께 다양한 전통 안주들을 경험해보세요.
#
# 4. **삼청동 "토속촌 삼계탕"** - 한여름에 특히 인기가 많은 삼계탕을 맛볼 수 있는 곳입니다. 신선한 재료로 만든 삼계탕은 영양가가 높고 맛도 뛰어난 유명한 음식점입니다.
#
# 5. **이태원 "마포갈매기"** - 이곳은 갈매기살, 즉 삼겹살의 한 종류를 전문으로 하는 식당입니다. 독특한 풍미의 고기를 숯불에 구워 맛볼 수 있으며, 다양한 소스와 함께 제공되어 더욱 맛있게 즐길 수 있습니다.
#
# 이 외에도 서울에는 다양한 음식점들이 많으니, 기회가 된다면 여러 곳을 방문해 보세요!
# 서울에서 대표적인 음식을 맛볼 수 있는 레스토랑 다섯 곳을 추천해드릴게요.
#
# 1. **광장시장 (Gwangjang Market)**
#    - 전통시장인 광장시장은 빈대떡, 육회, 떡볶이 등 한국의 대표적인 길거리 음식을 맛볼 수 있는 곳입니다. 다양한 먹거리를 즐기며 현지인들과 함께하는 분위기를 경험할 수 있습니다.
#
# 2. **한정식 전문점 '삼청동 수라간' (Sura-gang)**
#    - 전통 한정식을 제공하는 이곳은 정갈하고 아름다운 플레이팅과 함께 제철 재료를 활용한 다양한 반찬을 맛볼 수 있습니다. 전통적인 한국식 다이닝을 체험할 수 있습니다.
#
# 3. **부대찌개 '신사부대찌개' (Shinsa Budae Jjigae)**
#    - 부대찌개의 발상지로 알려진 이곳은 진한 국물과 풍부한 재료로 사랑받고 있습니다. 고기, 소시지, 라면 등을 활용한 푸짐한 한 그릇을 즐길 수 있습니다.
#
# 4. **갈비찜 '명동교자' (Myeongdong Kyoja)**
#    - 명동에 위치한 이 식당은 갈비찜과 칼국수로 유명합니다. 부드러운 갈비와 진한 국물은 물론, 쫄깃한 칼국수도 함께 즐길 수 있습니다.
#
# 5. **비빔밥 '토속촌 비빔밥' (Tosokchon Bibimbap)**
#    - 이곳은 전통 비빔밥을 현대적으로 재해석하여 선보입니다. 다양한 나물이 가득 담긴 비빔밥과 고소한 참기름 맛을 느낄 수 있습니다.
#
# 이 외에도 서울에는 다양한 전통 음식과 현대적인 맛을 동시에 즐길 수 있는 많은 식당들이 있습니다. 맛있게 즐기세요!
# 서울에는 전통 음식부터 현대적인 퓨전 요리까지 다양한 음식을 즐길 수 있는 레스토랑이 많이 있습니다. 아래는 서울을 대표하는 음식을 맛볼 수 있는 다섯 곳의 추천 레스토랑입니다.
#
# 1. **광장시장 (Gwangjang Market)**
#    - **음식:** 빈대떡, 마약김밥, 순대
#    - **설명:** 전통 재래시장으로서 다양한 한국 길거리 음식을 한자리에서 즐길 수 있습니다. 빈대떡과 마약김밥은 특히 유명합니다.
#
# 2. **토속촌 삼계탕 (Tosokchon Samgyetang)**
#    - **음식:** 삼계탕
#    - **설명:** 토속촌은 삼계탕으로 유명한 곳으로, 맛있는 인삼과 한방 재료로 우려낸 국물과 신선한 닭고기의 조화가 일품입니다.
#
# 3. **한일관 (Hanilkwan)**
#    - **음식:** 갈비찜, 불고기
#    - **설명:** 전통 한식을 재현한 레스토랑으로, 갈비찜과 불고기가 매우 맛있으며, 품질 높은 한식을 제공하는 곳입니다.
#
# 4. **미진 (Mijin)**
#    - **음식:** 우동, 덮밥
#    - **설명:** 일본식 우동과 덮밥을 전문으로 하는 레스토랑으로, 간단하면서도 깊은 맛을 내는 요리가 특징입니다. 한국의 면 요리와 입맛이 비슷한 점에서 인기가 많습니다.
#
# 5. **부산집 (Busanjip)**
#    - **음식:** 해물탕, 김치찌개
#    - **설명:** 해산물이 가득한 해물탕과 진한 맛의 김치찌개를 즐길 수 있는 곳으로, 지역 주민들에게도 사랑받는 인기 식당입니다.
#
# 이 외에도 서울에는 다양한 식당들이 있어 각 지역의 특색을 살린 요리를 맛볼 수 있습니다. 꼭 방문해 보시길 추천드립니다!
# 서울은 다양한 전통 음식과 현대적인 퓨전 요리를 즐길 수 있는 도시입니다. 다음은 서울을 대표하는 음식을 맛볼 수 있는 추천 레스토랑 5곳입니다.
#
# 1. **광장시장** - **빈대떡 및 마약김밥**
#    - 광장시장은 서울의 전통 시장 중 하나로, 다양한 길거리 음식을 즐길 수 있습니다. 특히 빈대떡과 마약김밥은 이곳의 대표적인 맛입니다.
#
# 2. **마포갈매기** - **갈매기살**
#    - 마포지역에서 유명한 갈비와 갈매기살을 전문으로 하는 레스토랑입니다. 고소하고 쫄깃한 갈매기살을 직접 구워 먹을 수 있는 즐거움이 있습니다.
#
# 3. **한남동** - **멜젤리 스시**
#    - 한남동에 위치한 이곳은 전통적인 스시가 아닌 퓨전 스시를 제공하는 레스토랑입니다. 한국의 재료를 활용한 독창적인 스시가 돋보입니다.
#
# 4. **부암동** - **재첩국**
#    - 부암동에 있는 이 식당은 재첩국과 같은 전통적인 서울 음식을 제공합니다. 특히 담백하고 깊은 맛의 국물이 일품입니다.
#
# 5. **종로** - **청진옥**
#    - 청진옥은 서울에서 유명한 평양냉면 전문점입니다. 시원한 육수와 쫄깃한 면발로 많은 사랑을 받고 있는 곳입니다.
#
# 각 레스토랑에서는 각기 다른 서울의 매력을 느낄 수 있으며, 전통 맛을 현대적으로 해석한 요리도 많이 있으니 한 번 방문해 보시길 추천합니다!
# 서울은 다양한 전통 음식과 현대적인 퓨전 요리를 즐길 수 있는 도시입니다. 서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5곳을 추천해 드릴게요.
#
# 1. **광장시장 (Gwangjang Market)**
#    전통 시장에서 비빔밥, 빈대떡, 마늘빵 등 다양한 한국 음식을 맛볼 수 있습니다. 특히, 광장시장의 빈대떡과 고르곤졸라 치즈를 얹은 누룽지 전은 반드시 드셔보세요.
#
# 2. **토속촌 삼계탕 (Tosokchon Samgyetang)**
#    삼계탕의 명소로, 부드러운 닭과 진한 국물, 인삼, 찹쌀, 마늘이 함께 조리되어 건강한 한 끼를 제공합니다. 많은 외국인과 관광객이 찾는 유명한 식당입니다.
#
# 3. **부암동 한정식 (Buam-dong Hanjeongsiik)**
#    한국 전통 한정식을 즐길 수 있는 곳으로, 여러 가지 반찬과 함께 나오는 메인 요리를 경험할 수 있습니다. 특히 계절 재료를 활용한 요리를 제공하여 신선함을 더합니다.
#
# 4. **쭈꾸미 타운 (Jjukkumi Town)**
#    서울의 식당가 중 하나인 홍대에 위치하고 있으며, 매콤한 쭈꾸미(작은 문어) 요리를 전문으로 합니다. 매운 양념과 함께 구워진 쭈꾸미는 특히 술안주로 인기가 높습니다.
#
# 5. **명동 교자 (Myeongdong Kyoja)**
#    칼국수와 만두 전문 레스토랑으로, 바삭한 만두와 진한 국물의 칼국수가 인기입니다. 명동 지역에 위치하여 관광객들이 자주 찾는 맛집입니다.
#
# 이 다섯 곳에서 서울의 맛과 문화를 충분히 즐기실 수 있을 것입니다!
# 서울에서 대표적인 음식을 맛볼 수 있는 레스토랑 몇 곳을 추천해 드리겠습니다.
#
# 1. **광장시장 (Gwangjang Market)**
#    전통 시장으로서 다양한 한국 음식을 경험할 수 있는 곳입니다. 특히 빈대떡, 마약김밥, 족발 등의 길거리 음식을 맛볼 수 있습니다. 시장 분위기를 즐기며 여러 가지 음식을 한 번에 체험할 수 있습니다.
#
# 2. **우래옥 (Wooraeok)**
#    한우 육회와 평양냉면이 유명한 레스토랑입니다. 전통적인 평양식 냉면을 맛볼 수 있으며, 정갈하고 고급스러운 한우 육회도 놓치지 말아야 할 메뉴입니다.
#
# 3. **토속촌 삼계탕 (Tosokchon Samgyetang)**
#    서울에서 유명한 삼계탕 집으로, 북경오리처럼 바삭한 피부를 가진 통계와 함께 속을 든든히 채운 약재와 한방 재료의 맛이 일품입니다. 여름철 보양식으로 특히 많은 사람들이 찾습니다.
#
# 4. **한방삼계탕 (Hanbang Samgyetang)**
#    한약재와 함께 조리된 삼계탕을 맛볼 수 있는 곳으로, 건강에 좋은 한방 재료가 가득한 삼계탕을 제공합니다. 특히 여름철에 많이 찾는 보양식입니다.
#
# 5. **동원참치 (Dongwon Tuna)**
#    신선한 참치를 사용하는 초밥과 회를 전문으로 하는 레스토랑입니다. 제철 생선으로 만든 스시와 신선한 회를 즐길 수 있으며, 한국에서의 일본식 해산물을 경험할 수 있는 훌륭한 선택입니다.
#
# 이 외에도 서울에는 다양한 음식점이 많으니, 방문하실 때마다 새로운 맛을 발견하실 수 있을 것입니다!
# 서울에서 대표적인 음식을 맛볼 수 있는 레스토랑 5곳을 추천해 드리겠습니다.
#
# 1. **광장시장** - **빈대떡 & 마약김밥**
#    - 광장시장은 전통 시장으로, 빈대떡, 마약김밥 등 길거리 음식을 즐길 수 있습니다. 빈대떡을 따뜻하게 구워주는 노점과 마약김밥이 유명한 집이 많으니 꼭 경험해 보세요.
#
# 2. **부암동** - **쌈지골**
#    - 쌈지골은 전통 한식을 즐길 수 있는 장소로 유명합니다. 제철 재료를 사용한 맛있는 반찬들과 함께 비빔밥이나 불고기를 즐길 수 있습니다. 분위기도 좋아서 서울의 감성을 느끼기에 적합한 곳입니다.
#
# 3. **동대문** - **신당동 떡볶이**
#    - 신당동은 떡볶이로 유명한 지역입니다. 다양한 스타일의 떡볶이를 제공하는 여러 가게가 있으며, 대표적으로 '신당동 떡볶이' 가게를 추천합니다. 매운 떡볶이와 함께 튀김을 즐기시면 좋습니다.
#
# 4. **이태원** - **부산아지매**
#    - 부산아지매는 부산식 해산물 요리를 제공하는 곳으로, 싱싱한 회와 해물찜을 맛볼 수 있습니다. 서울에 있는 부산의 맛을 느낄 수 있는 특별한 장소입니다.
#
# 5. **명동** - **명동교자**
#    - 칼국수와 만두로 유명한 명동교자는 언제나 많은 사람들이 찾는 인기 맛집입니다. 쫄깃한 면발과 진한 국물의 칼국수는 서울 방문 시 꼭 맛봐야 할 음식입니다.
#
# 이 다섯 곳은 서울의 다양한 지역과 대표 요리를 탐험할 수 있는 좋은 선택지입니다. 꼭 한번 가보시길 추천드립니다!
# Elapsed time: 9.17 seconds

# %% [markdown]
# ## sync

# %%
# sync 호출 시간 비교 5 times
